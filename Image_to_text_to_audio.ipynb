# %% [markdown]
# <a href="https://colab.research.google.com/github/prabh505/Image_to_Text_to_Audio/blob/main/Image_to_text_to_audio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# !pip install gTTS
# !pip install Pillow==9.0.0
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 4.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.2.1
#     Uninstalling click-8.2.1:
#       Successfully uninstalled click-8.2.1
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 MB 12.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for Pillow: filename=Pillow-9.0.0-cp311-cp311-linux_x86_64.whl size=1177677 sha256=e3b40573f0cca1ff99f59dc55ef36427a981244dbc53cf2526a9d93d508d498c
#   Stored in directory: /root/.cache/pip/wheels/0c/83/93/7ecd5a526f27268c0d6d47c5906dc7d368748226e281caf158
# Successfully built Pillow
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 11.2.1
# ...

# %%
import pytesseract
from PIL import Image
import gtts

# %%
img = Image.open('/content/new.png')
print(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=700x440 at 0x7EAAF869CD50>

# %%
result = pytesseract.image_to_string(img)
print(result)
tts = gtts.gTTS(result)
tts.save("hello.mp3")
# Out:
# It was the best of
# times, it was the worst
# of times, it was the age
# of wisdom, it was the
# age of foolishness...

# %%
from IPython.display import Audio
from google.colab import files

Audio("hello.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
